# %% [markdown]
# ## 1. Download and install VSCode
# URL: https://code.visualstudio.com/download
# ![c1.png](attachment:c1.png)

# %% [markdown]
# ![c2.png](attachment:c2.png)

# %% [markdown]
# ![c3.png](attachment:c3.png)

# %% [markdown]
# ### Pick the theme you like and click on "Mark Done"

# %% [markdown]
# ![c4.png](attachment:c4.png)

# %% [markdown]
# ### Install local language (like Chinese) for menu
# - Search "ms-client.vscode-language-pack-zh-hans" in resource window
# - **Chinese Pack:** https://marketplace.visualstudio.com/items?itemName=MS-CEINTL.vscode-language-pack-zh-hans

# %% [markdown]
# ## 2.Install related packages

# %% [markdown]
# ### 1) SSH Remote Develop
#
# **Name:** ms-vscode-remote.remote-ssh
#
# "ms-vscode-remote.remote-ssh-edit" and "ms-vscode.remote-explorer" are also installed with this package
# 1. Resources
# 2. Enter name in search bar
# 3. found the package and install it
# ![c5.png](attachment:c5.png)

# %% [markdown]
# ### 2) C++ Develop
# **Name:** ms-vscode.cpptools
# ![c6.png](attachment:c6.png)

# %% [markdown]
# ### 3) Python Develop
# **Name:** ms-python.python
# ![c7.png](attachment:c7.png)

# %% [markdown]
#  ## 3. Connect to Ubuntu through VSCode SSH
#  ![c8.png](attachment:c8.png)

# %% [markdown]
# ![c9.png](attachment:c9.png)
